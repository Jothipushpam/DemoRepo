# %%
x="first version"
print (x)
# Out:
# first version

# %%
y="second version"
print (y)
# Out:
# second version

# %%
c="third version"
print (c)
# Out:
# third version

# %%
d="fourth version"
print(d)
# Out:
# fourth version

# %%
g="fifth version"
print(g)
# Out:
# fifth version

# %%
m="sixth version"
print(m)
# Out:
# sixth version
